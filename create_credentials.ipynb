# %%
# .env

# %%
env_content = """
GOOGLE_API_KEY=AIzaSyBXv86jk7rAAweMY5PkTAjN1Eo7rGM23jU
"""

with open(".env","w") as file:
    file.write(env_content.strip())

    print(".env file created successfully!")
# Out:
# .env file created successfully!
