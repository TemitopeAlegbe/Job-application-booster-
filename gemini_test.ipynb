# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /opt/anaconda3/lib/python3.13/site-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (2.176.0)
# Requirement already satisfied: google-auth>=2.15.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: pydantic in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (2.10.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.13/site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.13/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.6.15)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic->google-generativeai) (2.27.1)

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.13/site-packages (1.1.0)

# %%
# import necessary libraries
import os
import streamlit as st
from dotenv import load_dotenv
from google import generativeai as genai

# %%
# get the API key from our environment variable
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
# configure the model
genai.configure()

# %%
# Load the model
model = genai.GenerativeModel('gemini-1.5-flash')

# %%
prompt = "What are the skills needed to study gen AI"

# %%
# generating the content
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# Studying Generative AI requires a multifaceted skillset, blending theoretical understanding with practical application. Here's a breakdown of the key skills needed:
#
# **I. Foundational Skills:**
#
# * **Mathematics:** A strong foundation in linear algebra (matrices, vectors, tensors), calculus (derivatives, gradients), probability, and statistics is crucial for understanding the underlying algorithms.  Deep learning relies heavily on these mathematical concepts.
# * **Programming:** Proficiency in Python is essential.  Most generative AI models and libraries (TensorFlow, PyTorch, Jax) are built using Python.  Familiarity with other languages like C++ might be beneficial for performance optimization in some cases.
# * **Computer Science Fundamentals:**  Understanding data structures, algorithms, and computational complexity is vital for efficient model training and deployment.  Knowledge of databases is helpful for managing large datasets.
#
# **II.  Specific AI/ML Skills:**
#
# * **Machine Learning (ML):** A comprehensive understanding of supervised, unsupervised, and reinforcement learning techniques is necessary.  Generative models often leverage a combination of these approaches.
# * **Deep Learning (DL):**  Profound knowledge of neural networks, including different architectures (Convolutional Neural Networks (CNNs), Recurrent Neural Networks (RNNs), Transformers, Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), Diffusion Models) is crucial.  You'll need to understand how these architectures work, their strengths and weaknesses, and how to train and optimize them.
# * **Natural Language Processing (NLP) (for text-based generative AI):** If focusing on text generation, strong NLP skills are essential, including tokenization, word embeddings (Word2Vec, GloVe, fastText), attention mechanisms, and language models (like BERT, GPT).
# * **Computer Vision (for image-based generative AI):**  If focusing on image generation, a strong understanding of computer vision techniques is needed, including image processing, feature extraction, and object detection.
#
# **III.  Practical Skills:**
#
# * **Model Training and Evaluation:**  Experience in training and fine-tuning deep learning models, including hyperparameter tuning, regularization techniques, and model evaluation metrics (e.g., precision, recall, F1-score, BLEU score for text).  Understanding bias and fairness in models is also critical.
# * **Data Handling and Preprocessing:**  Ability to collect, clean, preprocess, and manage large datasets is essential.  This includes handling missing data, dealing with imbalanced datasets, and feature engineering.
# * **Model Deployment and Optimization:**  Knowledge of deploying trained models to production environments (cloud platforms like AWS, Google Cloud, Azure) and optimizing their performance for speed and efficiency.
# * **Version Control (Git):**  Essential for managing code and collaborating with others.
#
# **IV.  Emerging Skills (Highly beneficial):**
#
# * **Prompt Engineering:**  The ability to craft effective prompts to guide generative AI models to produce desired outputs is becoming increasingly important.
# * **Model Explainability and Interpretability:**  Understanding techniques to interpret the decisions made by complex generative models is crucial for building trust and identifying potential biases.
# * **Ethical Considerations:**  Awareness of the ethical implications of generative AI, including potential biases, misuse, and societal impact, is vital.
#
#
# **V.  Resources and Learning:**
#
# * **Online Courses:** Coursera, edX, Udacity, fast.ai offer numerous courses on deep learning, NLP, and computer vision.
# * **Research Papers:** Staying up-to-date with the latest research papers on arXiv and other academic platforms is vital.
# * **Open-Source Projects:** Contributing to or studying open-source projects can provide valuable practical experience.
#
#
# This is not an exhaustive list, but it provides a solid foundation of the skills needed to effectively study generative AI. The specific skills you need will depend on your area of focus within generative AI (e.g., text, image, audio, video generation).  Start with the foundational skills and gradually build upon them as you progress.

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.13/site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /opt/anaconda3/lib/python3.13/site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)

# %%
# !pip install docx
# Out:
# Collecting docx
#   Downloading docx-0.2.4.tar.gz (54 kB)
#   Preparing metadata (setup.py) ... one
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.13/site-packages (from docx) (5.3.0)
# Requirement already satisfied: Pillow>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from docx) (11.1.0)
# Building wheels for collected packages: docx
#   DEPRECATION: Building 'docx' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'docx'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for docx (setup.py) ... one
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53894 sha256=cf59a4aaa59c1acdbf6a18d7d3306e971dce5e45794f316d7690a01020f8d561
#   Stored in directory: /Users/ezewholesale/Library/Caches/pip/wheels/eb/12/a3/0ba9b921d62f8f5253e74a59caa5c11a116bcf497e97eca94c
# Successfully built docx
# Installing collected packages: docx
# Successfully installed docx-0.2.4

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Collecting pdfminer.six==20250506 (from pdfplumber)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /opt/anaconda3/lib/python3.13/site-packages (from pdfplumber) (11.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-macosx_10_13_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pdfminer.six==20250506->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pdfminer.six==20250506->pdfplumber) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.21)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 9.2 MB/s eta 0:00:00a 0:00:01
# Downloading pypdfium2-4.30.1-py3-none-macosx_10_13_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.1 MB/s eta 0:00:00:--:--
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pdfplumber]3 [pdfplumber]x]
# Successfully installed pdfminer.six-20250506 pdfplumber-0.11.7 pypdfium2-4.30.1

# %%
# !pip install docx
# Out:
# Requirement already satisfied: docx in /opt/anaconda3/lib/python3.13/site-packages (0.2.4)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.13/site-packages (from docx) (5.3.0)
# Requirement already satisfied: Pillow>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from docx) (11.1.0)

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from python-docx) (4.12.2)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
